# %%
import numpy as np
import pandas as pd

# %%
def load_data(tag = "train"):
    return pd.read_csv('../ai4all_data/'+tag+'.csv')

# %%
train = load_data("train")
train_nona = train.dropna(how='all')
background = load_data("background")
train_nona = train.dropna(how='all')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2825: DtypeWarning: Columns (10025,10029,10032,10575,10578,10592,10607,10616,10631,10640,10655,10693,10712,10716,10740,10782,10787,10791,10796,10833,10865,10999,11030,11043,11127,11128,11234,11258,11282,11309,11310,11384,11394,11408,11409,11411,11412,11438,11441,11485,11490,11504,11508,11511,11514,11520,11527,11533,11539,11545,11546,11624,11629,11658,11672,11673,11678,11679,11680,11719,11721,11934,12160,12166,12168,12177,12183,12189,12199,12201,12203,12205,12216,12217,12228,12229,12239,12300,12316,12358,12367,12375,12402,12404,12408,12451,12453,12465,12467,12475,12481,12483,12496,12498,12520,12530,12531,12541,12599,12607,12623,12638,12650,12651,12663,12668,12715,12717,12735,12736,12758,12762,12772,12781,12788,12800,12801) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
print(train.shape)
print(train.count())
print(train_nona.shape)
print(train_nona.count())
# Out:
# (2121, 7)
# challengeID         2121
# gpa                 1165
# grit                1418
# materialHardship    1459
# eviction            1459
# layoff              1277
# jobTraining         1461
# dtype: int64
# (2121, 7)
# challengeID         2121
# gpa                 1165
# grit                1418
# materialHardship    1459
# eviction            1459
# layoff              1277
# jobTraining         1461
# dtype: int64

# %%
background
# Out:
#       challengeID  m1intmon  m1intyr  m1lenhr  m1lenmin  cm1twoc  cm1fint  \
# 0               1        -3      NaN       -3        40      NaN        0
# 1               2        -3      NaN        0        40      NaN        1
# 2               3        -3      NaN        0        35      NaN        1
# 3               4        -3      NaN        0        30      NaN        1
# 4               5        -3      NaN        0        25      NaN        1
# 5               6        -3      NaN        0        25      NaN        1
# 6               7        -3      NaN        0        35      NaN        1
# 7               8        -3      NaN        1        10      NaN        1
# 8               9        -3      NaN        0        30      NaN        1
# 9              10        -3      NaN        0        33      NaN        1
# 10             11        -3      NaN        0        40      NaN        1
# 11             12        -3      NaN        0        23      NaN        1
# ...
